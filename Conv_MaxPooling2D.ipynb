# %%
import tensorflow as tf
from tensorflow import keras

# 1. CARGAR DATOS (Igual que antes)
fashion_mnist = keras.datasets.fashion_mnist
(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()

# IMPORTANTE: Las CNNs esperan ver "Canales" (Colores).
# Como es blanco y negro, tenemos 1 canal. Redimensionamos a (28, 28, 1).
train_images = train_images.reshape((60000, 28, 28, 1)) / 255.0
test_images = test_images.reshape((10000, 28, 28, 1)) / 255.0

# 2. ARQUITECTURA CNN (El Ojo Biónico)
model = keras.Sequential([
    # CAPA 1: Extracción de características simples (bordes, líneas)
    # 32 filtros diferentes, cada uno de 3x3.
    keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)),
    keras.layers.MaxPooling2D((2, 2)), # Reduce la imagen a la mitad

    # CAPA 2: Extracción de características complejas (formas, curvas)
    # 64 filtros. Toma lo que descubrió la capa anterior y busca patrones más grandes.
    keras.layers.Conv2D(64, (3, 3), activation='relu'),
    keras.layers.MaxPooling2D((2, 2)),

    # CAPA 3: Clasificación (El Cerebro)
    # Ahora que tenemos mapas de características ("tiene cordones", "tiene suela"),
